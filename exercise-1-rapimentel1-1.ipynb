# %%
ice_cream_rating = 7
print(ice_cream_rating)

sleeping_rating = 8
print(sleeping_rating)
# Out:
# 7
# 8

# %%
first_name = input("what is your first name? ")
last_name = input("what is your last name? ")
print(f" {first_name} {last_name}")
# Out:
# what is your first name?  Valerie
# what is your last name?  Pimentel
#  Valerie Pimentel

# %%
happiness_rating = ((ice_cream_rating + sleeping_rating)/2)
print(happiness_rating)
# Out:
# 7.5

# %%
print(type(ice_cream_rating),type(first_name),type(happiness_rating))
# Out:
# <class 'int'> <class 'str'> <class 'float'>

# %% [markdown]
# Yes, all the data types made sense. It is correct that ice_cream_rating (7) is classified as an integer, first_name (valerie) is classified as string and happiness_rating (7.5) being a decimal value is classified as float.

# %%
print("my name is", first_name, "and I give eating ice cream a score of", ice_cream_rating, "out of 10!")
print("I am", first_name, last_name, "and my sleeping enjoyment rating is", sleeping_rating, "/ 10!")
print("Based on the factors above, my happiness rating is", happiness_rating, "out of 10, or", ((happiness_rating)/10)*100, "%")
# Out:
# my name is Valerie and I give eating ice cream a score of 7 out of 10!
# I am Valerie Pimentel and my sleeping enjoyment rating is 8 / 10!
# Based on the factors above, my happiness rating is 7.5 out of 10, or 75.0 %
